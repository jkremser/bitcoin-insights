// %% [markdown]
// # Analyse GitHub archives using GraphX

// %% [markdown]
// _Trying to detect open source communies based on contributions_

// %% [markdown]
// ## Setup the environment to work with GraphX and Json data

// %% [markdown]
// ### Import some github data

// %%
import sys.process._
if (!new java.io.File("/tmp/github.json").exists) {
  new java.net.URL("http://data.githubarchive.org/2015-01-01-15.json.gz")  #> new java.io.File("/tmp/github.json.gz") !!
  
  Seq("gunzip", "-f", "/tmp/github.json.gz")!!
}
// Out:
// <console>:71: warning: postfix operator !! should be enabled
// by making the implicit value scala.language.postfixOps visible.
// This can be achieved by adding the import clause 'import scala.language.postfixOps'
// or by setting the compiler option -language:postfixOps.
// See the Scaladoc for value scala.language.postfixOps for a discussion
// why the feature should be explicitly enabled.
//          new java.net.URL("http://data.githubarchive.org/2015-01-01-15.json.gz")  #> new java.io.File("/tmp/github.json.gz") !!
//                                                                                                                              ^
// <console>:73: warning: postfix operator !! should be enabled
// by making the implicit value scala.language.postfixOps visible.
//          Seq("gunzip", "-f", "/tmp/github.json.gz")!!
//                                                    ^
// import sys.process._
// res1: Any = ""

// %% [markdown]
// ### **The size of the data**

// %%
:sh du -h /tmp/github.json
// Out:
// 25M	/tmp/github.json
//
// import sys.process._

// %% [markdown]
// ## First some Spark manipulation

// %%
val raw = sparkContext.textFile("/tmp/github.json")
// Out:
// raw: org.apache.spark.rdd.RDD[String] = /tmp/github.json MapPartitionsRDD[1] at textFile at <console>:73

// %% [markdown]
// ### The number of lines in the file

// %%
raw.count
// Out:
// res6: Long = 11351
// 11351

// %% [markdown]
// ### Convert line to JSON _(simple Map of Maps)_

// %%
val json = raw.mapPartitions{ lines => 
  import com.fasterxml.jackson._
  import com.fasterxml.jackson.core._
  import com.fasterxml.jackson.databind._
  import com.fasterxml.jackson.module.scala._
  val mapper = new ObjectMapper()
  mapper.registerModule(DefaultScalaModule)
  lines.map(x => mapper.readValue(x, classOf[Map[String,Any]]))
}
// Out:
// json: org.apache.spark.rdd.RDD[Map[String,Any]] = MapPartitionsRDD[2] at mapPartitions at <console>:75

// %% [markdown]
// ### Let's look at the two first rows

// %%
json.take(2).toList
// Out:
// res9: List[Map[String,Any]] = List(Map(actor -> Map(gravatar_id -> "", url -> https://api.github.com/users/petroav, id -> 665991, login -> petroav, avatar_url -> https://avatars.githubusercontent.com/u/665991?), payload -> Map(description -> Solution to homework and assignments from MIT's 6.828 (Operating Systems Engineering). Done in my spare time., ref_type -> branch, ref -> master, master_branch -> master, pusher_type -> user), public -> true, id -> 2489651045, created_at -> 2015-01-01T15:00:00Z, repo -> Map(id -> 28688495, name -> petroav/6.828, url -> https://api.github.com/repos/petroav/6.828), type -> CreateEvent), Map(actor -> Map(gravatar_id -> "", url -> https://api.github.com/users/rspt, id -> 3854017, login -> rspt, avatar_url -> https://avatars.githubusercontent.com/u/38540...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona37513e916335ed9b777ef4cabaf8296&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1121379833&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1121379833"><li>
//               <a href="#tab1121379833-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1121379833-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1121379833"><div class="tab-pane" id="tab1121379833-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon7c6f80e92cb4afec72bb60f6cdaf92c9&quot;,&quot;dataInit&quot;:[{&quot;bitmap&quot;:84025377,&quot;elems&quot;:&quot;[Lscala.collection.immutable.HashMap;@3fe4ba96&quot;,&quot;size0&quot;:7},{&quot;bitmap&quot;:84025377,&quot;elems&quot;:&quot;[Lscala.collection.immutable.HashMap;@236f0e0c&quot;,&quot;size0&quot;:7}],&quot;genId&quot;:&quot;1811264595&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["bitmap","elems","size0"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon47663a03a7e7afaa752808512eb4a4ce&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon342e201235a9f55cdb8a938699cecbaa&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1121379833-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon0c6b6060ba484d85c2be1475bd3b6c3b&quot;,&quot;dataInit&quot;:[{&quot;bitmap&quot;:84025377,&quot;elems&quot;:&quot;[Lscala.collection.immutable.HashMap;@3fe4ba96&quot;,&quot;size0&quot;:7},{&quot;bitmap&quot;:84025377,&quot;elems&quot;:&quot;[Lscala.collection.immutable.HashMap;@236f0e0c&quot;,&quot;size0&quot;:7}],&quot;genId&quot;:&quot;576318802&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon7f07ea718f2751c29b9e24efde587c7d&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anondcf7e4558ee137d3768fe5b7c216e640&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// ## The graph part

// %% [markdown]
// We could use the *actors* and the *repos* as vertices, and use the *event* as relationship between them.
//
// There are *id*s for actor and repo, so we can directly use them in GraphX as such.

// %%
import org.apache.spark.rdd._
import org.apache.spark.graphx._
// Out:
// import org.apache.spark.rdd._
// import org.apache.spark.graphx._

// %% [markdown]
// ### RDD vertices {Actors U Repos}

// %%
val actors:RDD[(VertexId, (Short, String))] = json.map{ x => 
  val actor = x("actor").asInstanceOf[Map[String, Any]]
  val id = actor("id").toString.toLong
  val login = actor("login").toString
  (id, (0, login))
}
val repos:RDD[(VertexId, (Short, String))] = json.map{ x => 
  val repo = x("repo").asInstanceOf[Map[String, Any]]
  val id = repo("id").toString.toLong
  val name = repo("name").toString
  (id, (1, name))
}
val vertices:RDD[(VertexId, (Short, String))] = actors union repos
// Out:
// actors: org.apache.spark.rdd.RDD[(org.apache.spark.graphx.VertexId, (Short, String))] = MapPartitionsRDD[3] at map at <console>:83
// repos: org.apache.spark.rdd.RDD[(org.apache.spark.graphx.VertexId, (Short, String))] = MapPartitionsRDD[4] at map at <console>:89
// vertices: org.apache.spark.rdd.RDD[(org.apache.spark.graphx.VertexId, (Short, String))] = UnionRDD[5] at union at <console>:95

// %% [markdown]
// ### RDD of Edges

// %% [markdown]
// Now an **RDD** with the edges (including reverse ones, that is from repo to actor)

// %%
// None → repo to actor
// Some("PushEvent") → actor pushed on repo
val edges:RDD[Edge[Option[String]]] = json.flatMap { x =>
  val event = x.get("type").map(_.toString)
  val actor = x("actor").asInstanceOf[Map[String, Any]]("id").toString.toLong
  val repo = x("repo").asInstanceOf[Map[String, Any]]("id").toString.toLong
  List(Edge(actor, repo, event), Edge(actor, repo, None))
}
// Out:
// edges: org.apache.spark.rdd.RDD[org.apache.spark.graphx.Edge[Option[String]]] = MapPartitionsRDD[6] at flatMap at <console>:85

// %% [markdown]
// ### Graph

// %%
val graph = Graph(vertices, edges)
// Out:
// graph: org.apache.spark.graphx.Graph[(Short, String),Option[String]] = org.apache.spark.graphx.impl.GraphImpl@32d88be9

// %% [markdown]
// ## Open source working community

// %% [markdown]
// A very very simple example of such extraction would simply be to extract the connected components

// %% [markdown]
// So that, a component is the actors and repos having connections between them but not with other actor or repos. A connection being a collaboration.

// %% [markdown]
// ### Computing connected components

// %%
val cc = graph.connectedComponents
// Out:
// cc: org.apache.spark.graphx.Graph[org.apache.spark.graphx.VertexId,Option[String]] = org.apache.spark.graphx.impl.GraphImpl@3e1e8afd

// %% [markdown]
// The `cc` variable is the original graph but vertives' payload/properties is only the cluster to which is belongs. The cluster is characterized by the smallest `VertexId` in the cluster.

// %% [markdown]
// #### Number of connected components

// %% [markdown]
// Computing the number of clusters can easily be done by counting the number of distinct `payload` for the vertices.

// %%
<strong style="color: red">{cc.vertices.map(_._2).distinct.count}</strong>
// Out:
// res16: scala.xml.Elem = <strong style="color: red">4774</strong>
// <strong style="color: red">4774</strong>

// %% [markdown]
// ### Clusters by language

// %% [markdown]
// We can try to concentrate our analysis to specific languages, since we don't have the language information in the events data (we need extra call to the GitHub API for that) we'll take a naive approach, that is, **we'll only consider the repo having the language in their name** -- albeit it's not 100% safe.

// %% [markdown]
// #### Utility functions

// %% [markdown]
// The following function compute retrieves the cluster for a given cluster.

// %%
import org.apache.spark.SparkContext._
def cluster(lgg:String) = {
  // collect all repos for the language `lgg`
  val lggRepos:List[(VertexId, (Short, String))] = vertices.filter { x => 
                    x._2._1 /*vertex type*/ == 1 /*repo*/ && 
                    x._2._2/*repo name*/.toLowerCase.contains(lgg) //here we SHOULD exclude the prefix of '/'
                }.collect().toList
  // keep only the set
  // ***** IN A CLUSTER →→→ THIS NEEDS TO BE A BROADCAST VARIABLE *****wwwwzeqc
  val lggRepoIds:List[Long] = lggRepos.map(_._1).distinct
  // clusters "id" for these repos → BROADCAST
  val clusterIds:List[Long] = cc.vertices.filter(x => lggRepoIds.contains(x._1))
                            .map(_._2)
                            .collect()
                            .toList
  // return the vertices being clustered sorted by decreasing cardinality
  val clusters:List[(Long, Iterable[Long])] = cc.vertices.filter{ x => clusterIds.contains(x._2) }
                 .groupBy(_._2)
                 .mapValues(_.map(_._1))
                 .collect().toList
                 .sortBy(_._2.size)
                 .reverse
  clusters
}
// Out:
// import org.apache.spark.SparkContext._
// cluster: (lgg: String)List[(Long, Iterable[Long])]

// %% [markdown]
// Shows the list of repos and actors included in the given cluster

// %%
def showCluster(lgg:String, clusterIds:List[Long]) = {
  val c = graph.vertices
               .filter(x => clusterIds.contains(x._1))
               .collect().toList

  <div>
  <p><strong>Repos</strong></p>
  <ul>{ 
  c.collect { case (x, (1, r)) =>
           //show the repo
           val t = if (r.toLowerCase.contains(lgg)) <strong style="color: red;">{r}</strong> else r
             <li><a href={"http://github.com/"+r}>{t}</a></li> 
          }
  }</ul>
  <p><strong>Users</strong></p>
  <ul>{ 
  c.collect { case (x, (0, n)) =>
           //show the repo
             <li><a href={"http://github.com/"+n}>{n}</a></li> 
          }
  }</ul>
  </div>
}
// Out:
// showCluster: (lgg: String, clusterIds: List[Long])scala.xml.Elem

// %% [markdown]
// ## Javascript

// %%
val js = cluster("js")
// Out:
// js: List[(Long, Iterable[Long])] = List((2844,List(315596, 670440, 23082332, 95872, 1136652, 16960472, 1415488, 21872392, 119508, 26068656, 7944140, 4507612, 26809512, 28081156, 2057932, 3444336, 23338500, 2844, 188172, 36964, 6755852, 489576, 1230048, 24049584, 15204860, 6462268, 22430020, 1642136, 208340, 8749504, 27150864, 10364944, 22975952, 304332, 170820, 3591964, 4930716, 553444, 21108956, 2829600, 19821524, 959908, 3296912, 8665740, 7652428, 9896628, 2126244, 115904, 2606236, 2595532, 16809332, 14840449, 28573641, 261237, 10364781, 892945, 774297, 178965, 4371337, 6452529, 20407433, 28517589, 362985, 28538501, 183721, 28685197, 9914221, 10849933, 28452477, 18607529, 2029169, 16179237, 3106725, 1295961, 4927517, 21315049, 1719745, 453705, 1885237, 24847217, 13645881, 1039597, 282...

// %% [markdown]
// **Let's look at the 3 biggest clusters**

// %%
layout(3, js.take(3).map(r => html(showCluster("js", r._2.toList))))
// Out:
// res21: notebook.front.Widget = <widget>
// <div class="table-container table-responsive">
//     <table class="table">
//       <thead>
//       </thead>
//       <tbody><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/slackhq/SlackTextViewController">slackhq/SlackTextViewController</a></li><li><a href="http://github.com/emirozer/fake2db">emirozer/fake2db</a></li><li><a href="http://github.com/josephmisiti/awesome-machine-learning">josephmisiti/awesome-machine-learning</a></li><li><a href="http://github.com/zhxnlai/ZLSwipeableView">zhxnlai/ZLSwipeableView</a></li><li><a href="http://github.com/ddeboer/vatin">ddeboer/vatin</a></li><li><a href="http://github.com/omergul123/LLSimpleCamera">omergul123/LLSimpleCamera</a></li><li><a href="http://github.com/lexrus/VPNOn">lexrus/VPNOn</a></li><li><a href="http://github.com/clockfly/gearpump">clockfly/gearpump</a></li><li><a href="http://github.com/eigengo/lift">eigengo/lift</a></li><li><a href="http://github.com/papers-we-love/papers-we-love">papers-we-love/papers-we-love</a></li><li><a href="http://github.com/ongakuer/CircleIndicator">ongakuer/CircleIndicator</a></li><li><a href="http://github.com/coursera/pandas-ply">coursera/pandas-ply</a></li><li><a href="http://github.com/JigarM/UICollectionView-Swift">JigarM/UICollectionView-Swift</a></li><li><a href="http://github.com/snowplow/snowplow">snowplow/snowplow</a></li><li><a href="http://github.com/bro/bro">bro/bro</a></li><li><a href="http://github.com/gorhill/uBlock">gorhill/uBlock</a></li><li><a href="http://github.com/lexrus/vpn-deploy-playbook">lexrus/vpn-deploy-playbook</a></li><li><a href="http://github.com/OpenRA/OpenRA">OpenRA/OpenRA</a></li><li><a href="http://github.com/msiemens/PyGitUp">msiemens/PyGitUp</a></li><li><a href="http://github.com/twbs/bootstrap">twbs/bootstrap</a></li><li><a href="http://github.com/strukturag/spreed-webrtc">strukturag/spreed-webrtc</a></li><li><a href="http://github.com/michaelschramek/michaelschramek.github.io">michaelschramek/michaelschramek.github.io</a></li><li><a href="http://github.com/kozross/awesome-cl">kozross/awesome-cl</a></li><li><a href="http://github.com/rethinkdb/rethinkdb">rethinkdb/rethinkdb</a></li><li><a href="http://github.com/jostw/jos.tw">jostw/jos.tw</a></li><li><a href="http://github.com/imgix/imgix-emacs">imgix/imgix-emacs</a></li><li><a href="http://github.com/STRML/react-grid-layout">STRML/react-grid-layout</a></li><li><a href="http://github.com/CPAN-PRC/resources">CPAN-PRC/resources</a></li><li><a href="http://github.com/mutualmobile/MMDrawerController">mutualmobile/MMDrawerController</a></li><li><a href="http://github.com/ajalt/fuckitpy">ajalt/fuckitpy</a></li><li><a href="http://github.com/solnic/transproc">solnic/transproc</a></li><li><a href="http://github.com/Famous/famous">Famous/famous</a></li><li><a href="http://github.com/Matt-Esch/virtual-dom">Matt-Esch/virtual-dom</a></li><li><a href="http://github.com/aol/moloch">aol/moloch</a></li><li><a href="http://github.com/dongri/OAuthSwift">dongri/OAuthSwift</a></li><li><a href="http://github.com/statsmodels/statsmodels">statsmodels/statsmodels</a></li><li><a href="http://github.com/LipkeGu/OpenRA">LipkeGu/OpenRA</a></li><li><a href="http://github.com/drrb/java-rust-example">drrb/java-rust-example</a></li><li><a href="http://github.com/flarum/core">flarum/core</a></li><li><a href="http://github.com/h5bp/Front-end-Developer-Interview-Questions">h5bp/Front-end-Developer-Interview-Questions</a></li><li><a href="http://github.com/philipwalton/solved-by-flexbox">philipwalton/solved-by-flexbox</a></li><li><a href="http://github.com/wasabeef/awesome-android-libraries">wasabeef/awesome-android-libraries</a></li><li><a href="http://github.com/bclozel/spring-resource-handling">bclozel/spring-resource-handling</a></li><li><a href="http://github.com/enaqx/awesome-react">enaqx/awesome-react</a></li><li><a href="http://github.com/LnxPrgr3/crossfeed">LnxPrgr3/crossfeed</a></li><li><a href="http://github.com/myfreeweb/dotfiles">myfreeweb/dotfiles</a></li><li><a href="http://github.com/wasabeef/awesome-android-ui">wasabeef/awesome-android-ui</a></li><li><a href="http://github.com/jgeigerm/spotify2playmusic">j ...

// %% [markdown]
// ## Scala

// %%
val scala = cluster("scala")
// Out:
// scala: List[(Long, Iterable[Long])] = List((474633,List(5929896, 474633, 13899590)), (4078208,List(4078208, 28688755, 28689127)), (4402043,List(28684770, 4402043)), (3208807,List(28304675, 3208807)), (287491,List(27677770, 287491)), (1345438,List(1345438, 5016982)), (24870,List(28598724, 24870)), (3648029,List(3648029, 28049195)), (1145180,List(1145180, 4350848)), (289960,List(289960, 20581297)), (6007632,List(6204600, 6007632)), (648508,List(648508, 28133279)))

// %%
layout(4, scala.map(r => html(showCluster("scala", r._2.toList))))
// Out:
// res24: notebook.front.Widget = <widget>
// <div class="table-container table-responsive">
//     <table class="table">
//       <thead>
//       </thead>
//       <tbody><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/scalaz/scalaz"><strong style="color: red;">scalaz/scalaz</strong></a></li><li><a href="http://github.com/pavelfatin/patterns">pavelfatin/patterns</a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/0x414c">0x414c</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/itsvenkis/scala"><strong style="color: red;">itsvenkis/scala</strong></a></li><li><a href="http://github.com/itsvenkis/scala"><strong style="color: red;">itsvenkis/scala</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/itsvenkis">itsvenkis</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/Hossein-Boka/scalarest"><strong style="color: red;">Hossein-Boka/scalarest</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/Hossein-Boka">Hossein-Boka</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/shasdemir/scala-book"><strong style="color: red;">shasdemir/scala-book</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/shasdemir">shasdemir</a></li></ul>
//   </div></td></tr><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/ummels/scala-prioritymap"><strong style="color: red;">ummels/scala-prioritymap</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/ummels">ummels</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/Scalarm/scalarm_information_service"><strong style="color: red;">Scalarm/scalarm_information_service</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/kliput">kliput</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/okomok/vim-scala"><strong style="color: red;">okomok/vim-scala</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/okomok">okomok</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/nicolasstucki/scala-rrb-vector-thesis"><strong style="color: red;">nicolasstucki/scala-rrb-vector-thesis</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/nicolasstucki">nicolasstucki</a></li></ul>
//   </div></td></tr><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/ornicar/scalachess"><strong style="color: red;">ornicar/scalachess</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/Happy0">Happy0</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/inc-lc/ilc-scala"><strong style="color: red;">inc-lc/ilc-scala</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/Blaisorblade">Blaisorblade</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/ikeike443/Sublime-Scalariform"><strong style="color: red;">ikeike443/Sublime-Scalariform</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/fkennayo">fkennayo</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/shijinkui/scala-best-practices"><strong style="color: red;">shijinkui/scala-best-practices</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/shijinkui">shijinkui</a></li></ul>
//   </div></td></tr>
//       </tbody>
//     </table></div>

// %% [markdown]
// ## Spark ^^

// %%
val spark = cluster("spark")
// Out:
// spark: List[(Long, Iterable[Long])] = List((8108735,List(9467640, 17165658, 8108735, 25984335)), (6604878,List(28689340, 6604878, 26539815)), (10364991,List(28689305, 10364991)), (292693,List(28688640, 292693)), (548180,List(548180, 1614137)), (494304,List(494304, 28136522)))

// %%
layout(4, spark.map(r => html(showCluster("spark", r._2.toList))))
// Out:
// res27: notebook.front.Widget = <widget>
// <div class="table-container table-responsive">
//     <table class="table">
//       <thead>
//       </thead>
//       <tbody><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/apache/spark"><strong style="color: red;">apache/spark</strong></a></li><li><a href="http://github.com/tgaloppo/spark"><strong style="color: red;">tgaloppo/spark</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/tgaloppo">tgaloppo</a></li><li><a href="http://github.com/SparkQA">SparkQA</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/ScruffR/photon">ScruffR/photon</a></li><li><a href="http://github.com/spark/photon"><strong style="color: red;">spark/photon</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/ScruffR">ScruffR</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/SparkMonkay/Codes"><strong style="color: red;">SparkMonkay/Codes</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/SparkMonkay">SparkMonkay</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/mikemoraned/spark-play-sbt"><strong style="color: red;">mikemoraned/spark-play-sbt</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/mikemoraned">mikemoraned</a></li></ul>
//   </div></td></tr><tr><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/SparkDevNetwork/Rock"><strong style="color: red;">SparkDevNetwork/Rock</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/azturner">azturner</a></li></ul>
//   </div></td><td><div>
//   <p><strong>Repos</strong></p>
//   <ul><li><a href="http://github.com/rkuo/LearningSpark"><strong style="color: red;">rkuo/LearningSpark</strong></a></li></ul>
//   <p><strong>Users</strong></p>
//   <ul><li><a href="http://github.com/rkuo">rkuo</a></li></ul>
//   </div></td></tr>
//       </tbody>
//     </table></div>
